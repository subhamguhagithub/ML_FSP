# %% [markdown]
# <a href="https://colab.research.google.com/github/subhamguhagithub/ML_FSP/blob/main/chapter_appendix-tools-for-deep-learning/jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Using Jupyter Notebooks
# :label:`sec_jupyter`
#
#
# This section describes how to edit and run the code
# in each section of this book
# using the Jupyter Notebook. Make sure you have
# installed Jupyter and downloaded the
# code as described in
# :ref:`chap_installation`.
# If you want to know more about Jupyter see the excellent tutorial in
# their [documentation](https://jupyter.readthedocs.io/en/latest/).
#
#
# ## Editing and Running the Code Locally
#
# Suppose that the local path of the book's code is `xx/yy/d2l-en/`. Use the shell to change the directory to this path (`cd xx/yy/d2l-en`) and run the command `jupyter notebook`. If your browser does not do this automatically, open http://localhost:8888 and you will see the interface of Jupyter and all the folders containing the code of the book, as shown in :numref:`fig_jupyter00`.
#
# ![The folders containing the code of this book.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter00.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter00`
#
#
# You can access the notebook files by clicking on the folder displayed on the webpage.
# They usually have the suffix ".ipynb".
# For the sake of brevity, we create a temporary "test.ipynb" file.
# The content displayed after you click it is
# shown in :numref:`fig_jupyter01`.
# This notebook includes a markdown cell and a code cell. The content in the markdown cell includes "This Is a Title" and "This is text.".
# The code cell contains two lines of Python code.
#
# ![Markdown and code cells in the "text.ipynb" file.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter01.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter01`
#
#
# Double click on the markdown cell to enter edit mode.
# Add a new text string "Hello world." at the end of the cell, as shown in :numref:`fig_jupyter02`.
#
# ![Edit the markdown cell.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter02.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter02`
#
#
# As demonstrated in :numref:`fig_jupyter03`,
# click "Cell" $\rightarrow$ "Run Cells" in the menu bar to run the edited cell.
#
# ![Run the cell.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter03.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter03`
#
# After running, the markdown cell is shown in :numref:`fig_jupyter04`.
#
# ![The markdown cell after running.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter04.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter04`
#
#
# Next, click on the code cell. Multiply the elements by 2 after the last line of code, as shown in :numref:`fig_jupyter05`.
#
# ![Edit the code cell.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter05.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter05`
#
#
# You can also run the cell with a shortcut ("Ctrl + Enter" by default) and obtain the output result from :numref:`fig_jupyter06`.
#
# ![Run the code cell to obtain the output.](https://github.com/d2l-ai/d2l-en-colab/blob/master/img/jupyter06.png?raw=1)
# :width:`600px`
# :label:`fig_jupyter06`
#
#
# When a notebook contains more cells, we can click "Kernel" $\rightarrow$ "Restart & Run All" in the menu bar to run all the cells in the entire notebook. By clicking "Help" $\rightarrow$ "Edit Keyboard Shortcuts" in the menu bar, you can edit the shortcuts according to your preferences.
#
# ## Advanced Options
#
# Beyond local editing two things are quite important: editing the notebooks in the markdown format and running Jupyter remotely.
# The latter matters when we want to run the code on a faster server.
# The former matters since Jupyter's native ipynb format stores a lot of auxiliary data that is
# irrelevant to the content,
# mostly related to how and where the code is run.
# This is confusing for Git, making
# reviewing contributions very difficult.
# Fortunately there is an alternative---native editing in the markdown format.
#
# ### Markdown Files in Jupyter
#
# If you wish to contribute to the content of this book, you need to modify the
# source file (md file, not ipynb file) on GitHub.
# Using the notedown plugin we
# can modify notebooks in the md format directly in Jupyter.
#
#
# First, install the notedown plugin, run the Jupyter Notebook, and load the plugin:
#
# ```
# pip install d2l-notedown  # You may need to uninstall the original notedown.
# jupyter notebook --NotebookApp.contents_manager_class='notedown.NotedownContentsManager'
# ```
#
# You may also turn on the notedown plugin by default whenever you run the Jupyter Notebook.
# First, generate a Jupyter Notebook configuration file (if it has already been generated, you can skip this step).
#
# ```
# jupyter notebook --generate-config
# ```
#
# Then, add the following line to the end of the Jupyter Notebook configuration file (for Linux or macOS, usually in the path `~/.jupyter/jupyter_notebook_config.py`):
#
# ```
# c.NotebookApp.contents_manager_class = 'notedown.NotedownContentsManager'
# ```
#
# After that, you only need to run the `jupyter notebook` command to turn on the notedown plugin by default.
#
# ### Running Jupyter Notebooks on a Remote Server
#
# Sometimes, you may want to run Jupyter notebooks on a remote server and access it through a browser on your local computer. If Linux or macOS is installed on your local machine (Windows can also support this function through third-party software such as PuTTY), you can use port forwarding:
#
# ```
# ssh myserver -L 8888:localhost:8888
# ```
#
# The above string `myserver` is the address of the remote server.
# Then we can use http://localhost:8888 to access the remote server `myserver` that runs Jupyter notebooks. We will detail on how to run Jupyter notebooks on AWS instances
# later in this appendix.
#
# ### Timing
#
# We can use the `ExecuteTime` plugin to time the execution of each code cell in Jupyter notebooks.
# Use the following commands to install the plugin:
#
# ```
# pip install jupyter_contrib_nbextensions
# jupyter contrib nbextension install --user
# jupyter nbextension enable execute_time/ExecuteTime
# ```
#
# ## Summary
#
# * Using the Jupyter Notebook tool, we can edit, run, and contribute to each section of the book.
# * We can run Jupyter notebooks on remote servers using port forwarding.
#
#
# ## Exercises
#
# 1. Edit and run the code in this book with the Jupyter Notebook on your local machine.
# 1. Edit and run the code in this book with the Jupyter Notebook *remotely* via port forwarding.
# 1. Compare the running time of the operations $\mathbf{A}^\top \mathbf{B}$ and $\mathbf{A} \mathbf{B}$ for two square matrices in $\mathbb{R}^{1024 \times 1024}$. Which one is faster?
#
#
# [Discussions](https://discuss.d2l.ai/t/421)

# %%
# importing required modules
# !pip install pandas
# !pip install numpy
import pandas as pd
import numpy as np

# %%
# !pip install numpy

# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np

print(np.__version__)
print(pd.__version__)
# Out:
# 2.0.2
# 2.2.2

# %%
# disable warning message to appear
import warnings
warnings.filterwarnings('ignore')

# %%
# creating empty series
s = pd.Series()
print(s ,type(s), len(s), id(s))
# Out:
# Series([], dtype: object) <class 'pandas.core.series.Series'> 0 137327436600128

# %%
# create series from ndarray
arr_data = np.array([100, 200, 300, 400, 500])
print(arr_data, type(arr_data), arr_data.shape)
s = pd.Series(data = arr_data)
print(s)
# Out:
# [100 200 300 400 500] <class 'numpy.ndarray'> (5,)
# 0    100
# 1    200
# 2    300
# 3    400
# 4    500
# dtype: int64

# %%
arr_data = np.array([100, 200, 500, 400, 800])
print(arr_data, type(arr_data), arr_data.shape)
s = pd.Series(data = arr_data, copy = True)
print(s)
arr_data[0] = 999; s[1] = 888
print(arr_data, type(arr_data), arr_data.shape)
print(s)
# Out:
# [100 200 500 400 800] <class 'numpy.ndarray'> (5,)
# 0    100
# 1    200
# 2    500
# 3    400
# 4    800
# dtype: int64
# [999 200 500 400 800] <class 'numpy.ndarray'> (5,)
# 0    100
# 1    888
# 2    500
# 3    400
# 4    800
# dtype: int64

# %%
arr_data = np.array(['apple','guava','pineapple','banana','mango'])
print(arr_data)
s = pd.Series(data = arr_data,)
print(s)
s = pd.Series(data = arr_data)
print(s)
print(s[0], s[3])
print(s)
print(s[0])
print(s[3])
# Out:
# ['apple' 'guava' 'pineapple' 'banana' 'mango']
# 0        apple
# 1        guava
# 2    pineapple
# 3       banana
# 4        mango
# dtype: object
# 0        apple
# 1        guava
# 2    pineapple
# 3       banana
# 4        mango
# dtype: object
# apple banana
# 0        apple
# 1        guava
# 2    pineapple
# 3       banana
# 4        mango
# dtype: object
# apple
# banana

# %%
arr_data = np.array(['apple','guava','pineapple','banana','mango'])
print(arr_data)
s = pd.Series(data = arr_data, index = ['fruits-1','fruits-2','fruits-3','fruits-4','fruits-5'])
print(s)
print(s[0])
s = pd.Series(data = arr_data, index = ['fruits-1','fruits-2','fruits-3','fruits-4','fruits-5'])
print(s)
print(s['fruits-2'])
print(s[0])
# Out:
# ['apple' 'guava' 'pineapple' 'banana' 'mango']
# fruits-1        apple
# fruits-2        guava
# fruits-3    pineapple
# fruits-4       banana
# fruits-5        mango
# dtype: object
# apple
# fruits-1        apple
# fruits-2        guava
# fruits-3    pineapple
# fruits-4       banana
# fruits-5        mango
# dtype: object
# guava
# apple

# %%
arr_data = np.array(['apple', 'guava', 'pineapple', 'banana'])
print(arr_data)
s = pd.Series(data = arr_data)
print(s)
s = pd.Series(data = arr_data, index=[100, 101, 102, 103])
print(s)
print(s[100], s[103], type(s[103]))
# Out:
# ['apple' 'guava' 'pineapple' 'banana']
# 0        apple
# 1        guava
# 2    pineapple
# 3       banana
# dtype: object
# 100        apple
# 101        guava
# 102    pineapple
# 103       banana
# dtype: object
# apple banana <class 'str'>

# %%
#fetching data from a list
s = pd.Series(data = [111, 343, 222, 555, 444], index = ['red','green', 'blue', 'purple', 'white'])
print(s)
print(s['blue'], s[2])
print(s[0:4])
print(s[2:])
print(s[['blue','white','red']])
# Out:
# red       111
# green     343
# blue      222
# purple    555
# white     444
# dtype: int64
# 222 222
# red       111
# green     343
# blue      222
# purple    555
# dtype: int64
# blue      222
# purple    555
# white     444
# dtype: int64
# blue     222
# white    444
# red      111
# dtype: int64

# %%
s = pd.Series(data = [111, 343, 222, 555, 444], index = ['red','green', 'blue', 'purple', 'white'])
print(s)
print(s.sort_index())
print(s.sort_values())
print(s.argmax(),s.argmin ())
# Out:
# red       111
# green     343
# blue      222
# purple    555
# white     444
# dtype: int64
# blue      222
# green     343
# purple    555
# red       111
# white     444
# dtype: int64
# red       111
# blue      222
# green     343
# white     444
# purple    555
# dtype: int64
# 3 0

# %%
# creating series from a dictionary
dict_data = {'apple' : 105, 'pineapple' : 280, 'coconut' :650, 'mango':890}
print(dict_data , type(dict_data))
s = pd.Series(data = dict_data)
print(s)
print(s[1], s['pineapple'])
s = pd.Series(data = dict_data, index = ['mango', 'pineapple', 'apple', 'mango', 'orange'])
print(s)
# Out:
# {'apple': 105, 'pineapple': 280, 'coconut': 650, 'mango': 890} <class 'dict'>
# apple        105
# pineapple    280
# coconut      650
# mango        890
# dtype: int64
# 280 280
# mango        890.0
# pineapple    280.0
# apple        105.0
# mango        890.0
# orange         NaN
# dtype: float64

# %%
# creating series from a scalar
s = pd.Series(data = 5, index = [ 0, 1, 2, 3, 4, 5])
print(s)
s = pd.Series(data = 5, index = [22 , 11 , 44 , 33 , 22 , 11])
print(s)
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# 5    5
# dtype: int64
# 22    5
# 11    5
# 44    5
# 33    5
# 22    5
# 11    5
# dtype: int64

# %%
# creating series from a scalar
s = pd.Series(data = 5, index = [0, 1, 2, 3, 4, 5])
print(s)
s = pd.Series(data = 5, index = [22, 11, 44, 33, 22, 11])
print(s)
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# 5    5
# dtype: int64
# 22    5
# 11    5
# 44    5
# 33    5
# 22    5
# 11    5
# dtype: int64

# %%
# Class Assignment:
# input words: ['alaSKa', 'mango', 'dAd', 'coLLege']
# output words: ['alaSKa', 'dAd']
# All the alphabets must remain present in a single row of the keyboard.
# Only alphabets either in uppercase or in lowecase


input_words = ['alaSka', 'mango', 'dad', 'college']
row_set1 = set("qwertyuiop")
row_set2 = set("asdfghjkl")
row_set3 = set("zxcvbnm")
output_words = []
for word in  input_words:
  w = set(word.lower())
  if w.issubset(row_set1) or w.issubset(row_set2) or w.issubset(row_set3):
    output_words.append(word)
print(output_words)
# Out:
# ['alaSka', 'dad']

# %% [markdown]
# Data Frame Data Structure

# %%
user_data = [['alice',19,'F','student'], ['john',26,'M','student']]  # list of lists
user_columns = ['name','age','gender','job']
user1 = pd.DataFrame(data = user_data, columns = user_columns)
user1
# Out:
#     name  age gender      job
# 0  alice   19      F  student
# 1   john   26      M  student

# %%
user_data = dict(name=['eric','paul'], age=[22,58], gender=['M','F'], job=['student','manager'])  # dictionary
print(user_data)
user2 = pd.DataFrame(data = user_data)
user2
# Out:
# {'name': ['eric', 'paul'], 'age': [22, 58], 'gender': ['M', 'F'], 'job': ['student', 'manager']}
#    name  age gender      job
# 0  eric   22      M  student
# 1  paul   58      F  manager

# %%
user_data = {'name':['peter','julie'],'age':[33,44], 'gender':['M','F'],'job':['engineer','scientist']}
print(user_data)
user3 = pd.DataFrame(data = user_data)
user3
# Out:
# {'name': ['peter', 'julie'], 'age': [33, 44], 'gender': ['M', 'F'], 'job': ['engineer', 'scientist']}
#     name  age gender        job
# 0  peter   33      M   engineer
# 1  julie   44      F  scientist

# %%
# For Concatenation
users = pd.concat([user1, user2, user3])
user3 = pd.DataFrame(data = user_data)
users
# Out:
#     name  age gender        job
# 0  alice   19      F    student
# 1   john   26      M    student
# 0   eric   22      M    student
# 1   paul   58      F    manager
# 0  peter   33      M   engineer
# 1  julie   44      F  scientist

# %%
#data frame to ndarray
arr_data = users.to_numpy()
print(arr_data)
arr_data = np.array(users)
print(arr_data)
# Out:
# [['alice' 19 'F' 'student']
#  ['john' 26 'M' 'student']
#  ['eric' 22 'M' 'student']
#  ['paul' 58 'F' 'manager']
#  ['peter' 33 'M' 'engineer']
#  ['julie' 44 'F' 'scientist']]
# [['alice' 19 'F' 'student']
#  ['john' 26 'M' 'student']
#  ['eric' 22 'M' 'student']
#  ['paul' 58 'F' 'manager']
#  ['peter' 33 'M' 'engineer']
#  ['julie' 44 'F' 'scientist']]

# %% [markdown]
# Join Operation on Data Frame

# %%
data_dict = dict(name=['alice', 'john', 'eric', 'julie','tom'], height=[165, 180, 175, 160, 170], weight=[55, 80, 65, 45, 50])
print(data_dict)
user4 = pd.DataFrame(data = data_dict)
user4
# Out:
# {'name': ['alice', 'john', 'eric', 'julie', 'tom'], 'height': [165, 180, 175, 160, 170], 'weight': [55, 80, 65, 45, 50]}
#     name  height  weight
# 0  alice     165      55
# 1   john     180      80
# 2   eric     175      65
# 3  julie     160      45
# 4    tom     170      50

# %%
#inner join : All matching rows from both tables
merge_inner = pd.merge(users, user4, on = 'name')  # by default inner join
merge_inner
# Out:
#     name  age gender        job  height  weight
# 0  alice   19      F    student     165      55
# 1   john   26      M    student     180      80
# 2   eric   22      M    student     175      65
# 3  julie   44      F  scientist     160      45

# %%
merge_inner = pd.merge(users, user4, on = 'name', how = 'inner')  # by default inner join
merge_inner
# Out:
#     name  age gender        job  height  weight
# 0  alice   19      F    student     165      55
# 1   john   26      M    student     180      80
# 2   eric   22      M    student     175      65
# 3  julie   44      F  scientist     160      45

# %%
# left outer join: All rows from first and matching from second dataframes
merge_left = pd.merge(users, user4, on = 'name', how = 'left')
merge_left
# Out:
#     name  age gender        job  height  weight
# 0  alice   19      F    student   165.0    55.0
# 1   john   26      M    student   180.0    80.0
# 2   eric   22      M    student   175.0    65.0
# 3   paul   58      F    manager     NaN     NaN
# 4  peter   33      M   engineer     NaN     NaN
# 5  julie   44      F  scientist   160.0    45.0

# %%
# right outer join: All rows from second and matching rows from first dataframes
merge_right = pd.merge(users, user4, on = 'name', how = 'right')
merge_right
# Out:
#     name   age gender        job  height  weight
# 0  alice  19.0      F    student     165      55
# 1   john  26.0      M    student     180      80
# 2   eric  22.0      M    student     175      65
# 3  julie  44.0      F  scientist     160      45
# 4    tom   NaN    NaN        NaN     170      50

# %%
# right outer join: All rows matching and not matching from both datframes
merge_outer = pd.merge(users, user4, on = 'name', how = 'outer')
merge_outer
# Out:
#     name   age gender        job  height  weight
# 0  alice  19.0      F    student   165.0    55.0
# 1   eric  22.0      M    student   175.0    65.0
# 2   john  26.0      M    student   180.0    80.0
# 3  julie  44.0      F  scientist   160.0    45.0
# 4   paul  58.0      F    manager     NaN     NaN
# 5  peter  33.0      M   engineer     NaN     NaN
# 6    tom   NaN    NaN        NaN   170.0    50.0

# %%
# outer join: All rows matching and not matching from both dataframes
merge_outer = pd.merge(users, user4, on='name', how='outer')
merge_outer
# Out:
#     name   age gender        job  height  weight
# 0  alice  19.0      F    student   165.0    55.0
# 1   eric  22.0      M    student   175.0    65.0
# 2   john  26.0      M    student   180.0    80.0
# 3  julie  44.0      F  scientist   160.0    45.0
# 4   paul  58.0      F    manager     NaN     NaN
# 5  peter  33.0      M   engineer     NaN     NaN
# 6    tom   NaN    NaN        NaN   170.0    50.0

# %%
df = users # Define df using the 'users' DataFrame
df.head(2)
# Out:
#     name  age gender      job
# 0  alice   19      F  student
# 1   john   26      M  student

# %%
df = users
df.tail(3)
# Out:
#     name  age gender        job
# 1   paul   58      F    manager
# 0  peter   33      M   engineer
# 1  julie   44      F  scientist
